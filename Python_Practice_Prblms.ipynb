# %% [markdown]
# <a href="https://colab.research.google.com/github/amalendukithu06-cyber/DSA/blob/main/Python_Practice_Prblms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("Enter your name: ")
print("Welcome to Data Analytics,", name)
# Out:
# Enter your name: amalendu
# Welcome to Data Analytics, amalendu

# %%
snack = "Pizza"
print("I love munching on", snack, "during meetings!")
# Out:
# I love munching on Pizza during meetings!

# %%
tasks = 15
next_week = tasks * 2
print(next_week)
# Out:
# 30

# %%
income = 30000
expenses = 20000
savings = income - expenses
print("Savings =", savings)
# Out:
# Savings = 10000

# %%
rating = int(input("Enter rating (1-5): "))

if rating > 3:
    print("Above average")
else:
    print("Average or below")
# Out:
# Enter rating (1-5): 5
# Above average

# %%
last_month = 50
this_month = 75
next_month = 100

average = (last_month + this_month + next_month) / 3
print("Average =", average)
# Out:
# Average = 75.0

# %%
principal = 500
rate = 4
time = 3

interest = (principal * rate * time) / 100
total = principal + interest

print("Interest =", interest)
print("Total amount =", total)
# Out:
# Interest = 60.0
# Total amount = 560.0

# %%
guests = 10
slices_per_guest = 1
slices_per_cake = 8

total_slices = guests * slices_per_guest
cakes = (total_slices + slices_per_cake - 1) // slices_per_cake

print("Cakes needed =", cakes)
# Out:
# Cakes needed = 2

# %%
text = "Data Analytics"

if len(text) > 10:
    print("The text has more than 10 characters")
else:
    print("The text has 10 or fewer characters")
# Out:
# The text has more than 10 characters

# %%
product_A_sales = 250
product_B_sales = 300

if product_A_sales > product_B_sales:
    print("Product A sold more")
else:
    print("Product B sold more")
# Out:
# Product B sold more

# %%
scholarship = 750
total = 1000

percentage = (scholarship / total) * 100

print("Scholarship percentage =", percentage, "%")
print("Congratulations!")
# Out:
# Scholarship percentage = 75.0 %
# Congratulations!

# %%
favorite_color = "Blue"
print(favorite_color)
# Out:
# Blue

# %%
a = 10
b = 20

sum = a + b
print(sum)
# Out:
# 30

# %%
length = 10
width = 5

area = length * width
print("Area =", area)
# Out:
# Area = 50

# %%
num = 15

if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Odd

# %%
a = 10
b = 20
c = 30

average = (a + b + c) / 3
print("Average =", average)
# Out:
# Average = 20.0

# %%
import math

radius = 7

area = math.pi * radius ** 2
print("Area =", area)
# Out:
# Area = 153.93804002589985

# %%
text = "Python"

if len(text) > 6:
    print("More than 6 characters")
else:
    print("6 or fewer characters")
# Out:
# 6 or fewer characters

# %%
num1 = 15
num2 = 25

if num1 > num2:
    print("Maximum =", num1)
else:
    print("Maximum =", num2)
# Out:
# Maximum = 25

# %%
total_marks = 500
obtained_marks = 400

percentage = (obtained_marks / total_marks) * 100

print("Percentage =", percentage, "%")
# Out:
# Percentage = 80.0 %

# %%
text = input("Enter a string value: ")

for char in text:
    print(char, "=", text.count(char))
# Out:
# Enter a string value: 5
# 5 = 1

# %%
def maximum(a, b, c):
    return max(a, b, c)

print(maximum(34, 12, 7))
# Out:
# 34

# %%
def exponent(base, exp):
    return base ** exp

base = int(input("Enter the base: "))
exp = int(input("Enter the exponent: "))

print(exponent(base, exp))
# Out:
# Enter the base: 2
# Enter the exponent: 2
# 4

# %%
def sum_of_cubes(n):
    total = 0

    for i in range(1, n):
        total += i ** 3

    return total

print(sum_of_cubes(4))
# Out:
# 36

# %%
for i in range(1, 11):
    if i % 2 == 0 and i % 5 == 0:
        print("FizzBuzz")
    elif i % 2 == 0:
        print("Fizz")
    elif i % 5 == 0:
        print("Buzz")
    else:
        print(i)
# Out:
# 1
# Fizz
# 3
# Fizz
# Buzz
# Fizz
# 7
# Fizz
# 9
# FizzBuzz

# %%
numbers = [2, 3, 4, 2, 5, 2]

most_frequent = max(numbers, key=numbers.count)

print(most_frequent)
# Out:
# 2

# %%
numbers = [2, 1, 3, 1]

total = 0

for number in numbers:
    total += number ** 2

print(total)
# Out:
# 15

# %%
for i in range(1, 16):
    if i % 2 == 0:
        print(i, "- even")
    else:
        print(i, "- odd")
# Out:
# 1 - odd
# 2 - even
# 3 - odd
# 4 - even
# 5 - odd
# 6 - even
# 7 - odd
# 8 - even
# 9 - odd
# 10 - even
# 11 - odd
# 12 - even
# 13 - odd
# 14 - even
# 15 - odd

# %%
fahrenheit = float(input("Temperature in Fahrenheit = "))

celsius = (fahrenheit - 32) * 5 / 9

print("Temperature in Celsius =", celsius)
# Out:
# Temperature in Fahrenheit = 41
# Temperature in Celsius = 5.0

# %%
def factorial(n):
    result = 1

    for i in range(1, n + 1):
        result *= i

    return result

num = int(input("Enter a number: "))

print(factorial(num))
# Out:
# Enter a number: 3
# 6

# %%
num = int(input("Enter a number: "))

total = 0

while num > 0:
    digit = num % 10
    total += digit
    num //= 10

print("Sum of digits =", total)
# Out:
# Enter a number: 1234
# Sum of digits = 10

# %%
def factorial(n):
    result = 1

    for i in range(1, n + 1):
        result *= i

    return result

num = int(input("Enter a number: "))

print("Factorial =", factorial(num))
# Out:
# Enter a number: 5
# Factorial = 120

# %%
text = input("Enter a word or phrase: ")

text = text.replace(" ", "").lower()

if text == text[::-1]:
    print("Palindrome")
else:
    print("Not a palindrome")
# Out:
# Enter a word or phrase: 121
# Palindrome

# %%
text = input("Enter a sentence: ")

vowels = 0
consonants = 0

for char in text.lower():
    if char.isalpha():
        if char in "aeiou":
            vowels += 1
        else:
            consonants += 1

print("Vowels =", vowels)
print("Consonants =", consonants)
# Out:
# Enter a sentence: This is an apple
# Vowels = 5
# Consonants = 8

# %%
list1 = [1, 2, 3, 4, 5]
list2 = [3, 4, 5, 6, 7]

common = []

for item in list1:
    if item in list2:
        common.append(item)

print("Common elements =", common)
# Out:
# Common elements = [3, 4, 5]

# %%
text = input("Enter a string: ")

frequency = {}

for char in text:
    if char in frequency:
        frequency[char] += 1
    else:
        frequency[char] = 1

print(frequency)
# Out:
# Enter a string: 235
# {'2': 1, '3': 1, '5': 1}

# %%
year = int(input("Enter a year: "))

if year % 400 == 0 or (year % 4 == 0 and year % 100 != 0):
    print("Leap year")
else:
    print("Not a leap year")
# Out:
# Enter a year: 2018
# Not a leap year

# %%
num = int(input("Enter a number: "))

if num > 1:
    for i in range(2, num):
        if num % i == 0:
            print("Not a prime number")
            break
    else:
        print("Prime number")
else:
    print("Not a prime number")
# Out:
# Enter a number: 1
# Not a prime number

# %%
n = int(input("Enter number of terms: "))

a = 0
b = 1

for i in range(n):
    print(a, end=" ")
    a, b = b, a + b
# Out:
# Enter number of terms: 5
# 0 1 1 2 3

# %%
import math

a = float(input("Enter a: "))
b = float(input("Enter b: "))
c = float(input("Enter c: "))

discriminant = b ** 2 - 4 * a * c

if discriminant > 0:
    root1 = (-b + math.sqrt(discriminant)) / (2 * a)
    root2 = (-b - math.sqrt(discriminant)) / (2 * a)

    print("Root 1 =", root1)
    print("Root 2 =", root2)

elif discriminant == 0:
    root = -b / (2 * a)
    print("Both roots are =", root)

else:
    print("No real roots")
# Out:
# Enter a: 5
# Enter b: 4
# Enter c: 2
# No real roots
